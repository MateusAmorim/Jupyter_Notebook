# %% [markdown]
# <a href="https://colab.research.google.com/github/MateusAmorim/Python/blob/master/MicrodadosCovid_IBGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pprint import pprint
from matplotlib import pyplot
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv("/content/drive/MyDrive/BANCOS_DE_DADOS/microdados.csv", encoding="UTF-8", sep=",")

df.head()
# Out:
#     ano  mes  semana sigla_uf  capital  rm_ride  estrato        upa  v1008  \
# 0  2020    5       2       AC      NaN      NaN  1250010  120000055      1
# 1  2020    5       2       AC      NaN      NaN  1250010  120000055      1
# 2  2020    5       2       AC      NaN      NaN  1250010  120000055      1
# 3  2020    5       1       AC      NaN      NaN  1250010  120000055      2
# 4  2020    5       1       AC      NaN      NaN  1250010  120000055      2
#
#    v1016  ...  f001  f0021  f0022  f002a1  f002a2  f002a3  f002a4  f002a5  \
# 0      1  ...     2    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 1      1  ...     2    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 2      1  ...     2    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 3      1  ...     1    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 4      1  ...     1    NaN    NaN     NaN     NaN     NaN     NaN     NaN
#
#    f0061  f006
# 0      1   3.0
# 1      1   3.0
# 2      1   3.0
# ...

# %%
pprint(df)
# Out:
#           ano  mes  semana sigla_uf  capital  rm_ride  estrato        upa  \
# 0        2020    5       2       AC      NaN      NaN  1250010  120000055
# 1        2020    5       2       AC      NaN      NaN  1250010  120000055
# 2        2020    5       2       AC      NaN      NaN  1250010  120000055
# 3        2020    5       1       AC      NaN      NaN  1250010  120000055
# 4        2020    5       1       AC      NaN      NaN  1250010  120000055
# ...       ...  ...     ...      ...      ...      ...      ...        ...
# 2650454  2020   11       2       TO      NaN      NaN  1752011  170032077
# 2650455  2020   11       1       TO      NaN      NaN  1752011  170032077
# 2650456  2020   11       1       TO      NaN      NaN  1752011  170032077
# 2650457  2020   11       1       TO      NaN      NaN  1752011  170032077
# 2650458  2020   11       3       TO      NaN      NaN  1752011  170032077
#
#          v1008  v1016  ...  f001  f0021  f0022  f002a1  f002a2  f002a3  \
# ...

# %%
a = df['ano']

# %%
b = df['mes']

# %%
c = df['semana']

# %%
d = df['sigla_uf']

# %%
e = df['estrato']

# %%
f = df['upa']

# %%
g = df['b009d']

# %%
x = df['sigla_uf']
y = df['estrato']

# %%
plt.figure(figsize=(30,10))
plt.plot(x,y)
plt.title('sei lá')
plt.xlabel("sigla_uf")
plt.ylabel("estrato")
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.bar(x,y)
plt.title('Cotação do Dólar (Maio e Junho de 2022)')
plt.xlabel("Data")
plt.ylabel("USD-BRL")
plt.show()
