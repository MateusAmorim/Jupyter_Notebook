# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import csv

with open("C:/Users/USUÁRIO/Desktop/jupyter/cereal.csv", "r") as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=",")
    for i, linha in enumerate(arquivo_csv):
        if i == 0:
            print("Cabeçalho: " + str(linha))
        else:
            print("Valor: " + str(linha))
# Out:
# Cabeçalho: ['name;mfr;type;calories;protein;fat;sodium;fiber;carbo;sugars;potass;vitamins;shelf;weight;cups;rating']
# Valor: ['String;Categorical;Categorical;Int;Int;Int;Int;Float;Float;Int;Int;Int;Int;Float;Float;Float']
# Valor: ['100% Bran;N;C;70;4;1;130;10;5;6;280;25;3;1;0.33;68.402973']
# Valor: ['100% Natural Bran;Q;C;120;3;5;15;2;8;8;135;0;3;1;1;33.983679']
# Valor: ['All-Bran;K;C;70;4;1;260;9;7;5;320;25;3;1;0.33;59.425505']
# Valor: ['All-Bran with Extra Fiber;K;C;50;4;0;140;14;8;0;330;25;3;1;0.5;93.704912']
# Valor: ['Almond Delight;R;C;110;2;2;200;1;14;8;-1;25;3;1;0.75;34.384843']
# Valor: ['Apple Cinnamon Cheerios;G;C;110;2;2;180;1.5;10.5;10;70;25;1;1;0.75;29.509541']
# Valor: ['Apple Jacks;K;C;110;2;0;125;1;11;14;30;25;2;1;1;33.174094']
# Valor: ['Basic 4;G;C;130;3;2;210;2;18;8;100;25;3;1.33;0.75;37.038562']
# Valor: ['Bran Chex;R;C;90;2;1;200;4;15;6;125;25;1;1;0.67;49.120253']
# Valor: ['Bran Flakes;P;C;90;3;0;210;5;13;5;190;25;3;1;0.67;53.313813']
# ...

# %%
df1 = pd.read_csv( "C:/Users/USUÁRIO/Desktop/jupyter/cereal.csv", sep=";", error_bad_lines = False)
print(df1)
# Out:
#                          name          mfr         type calories protein  fat  \
# 0                      String  Categorical  Categorical      Int     Int  Int
# 1                   100% Bran            N            C       70       4    1
# 2           100% Natural Bran            Q            C      120       3    5
# 3                    All-Bran            K            C       70       4    1
# 4   All-Bran with Extra Fiber            K            C       50       4    0
# ..                        ...          ...          ...      ...     ...  ...
# 73                    Triples            G            C      110       2    1
# 74                       Trix            G            C      110       1    1
# 75                 Wheat Chex            R            C      100       3    1
# 76                   Wheaties            G            C      100       3    1
# 77        Wheaties Honey Gold            G            C      110       2    1
#
# ...

# %%
with open("C:/Users/USUÁRIO/Desktop/jupyter/cereal.csv") as f:
    len_csv = sum(1 for line in f)

number_of_skipped_rows = len_csv - len(df1)
number_of_skipped_rows
# Out:
# 1

# %%
print(df1)
# Out:
#                          name          mfr         type calories protein  fat  \
# 0                      String  Categorical  Categorical      Int     Int  Int
# 1                   100% Bran            N            C       70       4    1
# 2           100% Natural Bran            Q            C      120       3    5
# 3                    All-Bran            K            C       70       4    1
# 4   All-Bran with Extra Fiber            K            C       50       4    0
# ..                        ...          ...          ...      ...     ...  ...
# 73                    Triples            G            C      110       2    1
# 74                       Trix            G            C      110       1    1
# 75                 Wheat Chex            R            C      100       3    1
# 76                   Wheaties            G            C      100       3    1
# 77        Wheaties Honey Gold            G            C      110       2    1
#
# ...

# %%
df1.head()
# Out:
#                         name          mfr         type calories protein  fat  \
# 0                     String  Categorical  Categorical      Int     Int  Int
# 1                  100% Bran            N            C       70       4    1
# 2          100% Natural Bran            Q            C      120       3    5
# 3                   All-Bran            K            C       70       4    1
# 4  All-Bran with Extra Fiber            K            C       50       4    0
#
#   sodium  fiber  carbo sugars potass vitamins shelf weight   cups     rating
# 0    Int  Float  Float    Int    Int      Int   Int  Float  Float      Float
# 1    130     10      5      6    280       25     3      1   0.33  68.402973
# 2     15      2      8      8    135        0     3      1      1  33.983679
# 3    260      9      7      5    320       25     3      1   0.33  59.425505
# 4    140     14      8      0    330       25     3      1    0.5  93.704912

# %%
#df.info()
df1.describe().transpose()
# Out:
#          count unique     top freq
# name        78     78  String    1
# mfr         78      8       K   23
# type        78      3       C   74
# calories    78     12     110   29
# protein     78      7       3   28
# fat         78      6       1   30
# sodium      78     28       0    9
# fiber       78     14       0   19
# carbo       78     23      13    8
# sugars      78     18       3   13
# potass      78     37     110    5
# vitamins    78      4      25   63
# shelf       78      4       3   36
# weight      78      8       1   64
# cups        78     13       1   30
# rating      78     78   Float    1
