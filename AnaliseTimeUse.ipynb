# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv( "C:/Users/USUÁRIO/Desktop/jupyter/TimeUse.csv", sep=",")
print(df)
# Out:
#         SEX                                  GEO/ACL00  Total Personal care  \
# 0     Males                                    Belgium  24:00         10:45
# 1     Males                                   Bulgaria  24:00         11:54
# 2     Males  Germany (including  former GDR from 1991)  24:00         10:40
# 3     Males                                    Estonia  24:00         10:35
# 4     Males                                      Spain  24:00         11:11
# 5     Males                                     France  24:00         11:44
# 6     Males                                      Italy  24:00         11:16
# 7     Males                                     Latvia  24:00         10:46
# 8     Males                                  Lithuania  24:00         10:53
# 9     Males                                     Poland  24:00         10:44
# 10    Males                                   Slovenia  24:00         10:31
# ...

# %%
#df.info()
df.describe().transpose()
# Out:
#                                                    count unique      top freq
# SEX                                                   28      2    Males   14
# GEO/ACL00                                             28     14  Belgium    2
# Total                                                 28      1    24:00   28
# Personal care                                         28     26    11:11    2
# Sleep                                                 28     23     8:35    3
# Eating                                                28     22     1:26    4
# Other and/or unspecified personal care                28     20     0:41    3
# Employment, related activities and travel as pa...    28     27     3:48    2
# Main and second job and related travel                28     27     3:46    2
# Activities related to employment and unspecifie...    28      7     0:02    7
# Study                                                 28     15     0:15    4
# ...

# %%
df.head()
# Out:
#      SEX                                  GEO/ACL00  Total Personal care  \
# 0  Males                                    Belgium  24:00         10:45
# 1  Males                                   Bulgaria  24:00         11:54
# 2  Males  Germany (including  former GDR from 1991)  24:00         10:40
# 3  Males                                    Estonia  24:00         10:35
# 4  Males                                      Spain  24:00         11:11
#
#   Sleep Eating Other and/or unspecified personal care  \
# 0  8:15   1:49                                   0:42
# 1  9:08   2:07                                   0:39
# 2  8:08   1:43                                   0:49
# 3  8:24   1:19                                   0:52
# 4  8:36   1:47                                   0:48
#
#   Employment, related activities and travel as part of/during main and second job  \
# 0                                               3:07
# 1                                               3:32
# ...
